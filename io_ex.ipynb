# %% [markdown]
# # Input/ Output
# ## An Ensemble

# %%
from utils.pack import Pack
from utils.agent import Agent
from utils.metrics import ThoughtDiversity
from utils.neuron import Neuron
from collections import defaultdict
import networkx as nx
from utils.transducer import Transducer
import numpy as np

# %% [markdown]
# ## Pack

# %%
learning_to_act = "chroma_db/agent_ltoa"
system_neural_diversity = "chroma_db/agent_snd_m2"  # "documents/meowsmeowing.pdf"
foundational_models = "chroma_db/agent_foundation"
norbet_cog = "chroma_db/agent_norbert_m2"
viz_quant = "chroma_db/agent_quant"
cot_path = "chroma_db/agent_cot"

embedding_params = [
    ["facebook-dpr-ctx_encoder-multiset-base", 200, 25, 0.9],
    ["sentence-transformers/all-MiniLM-L6-v2", 200, 25, 0.9],
    ["facebook-dpr-ctx_encoder-multiset-base", 200, 25, 0.5],
    ["sentence-transformers/all-mpnet-base-v2", 200, 25, 0.5],
    ["facebook-dpr-ctx_encoder-multiset-base", 200, 25, 0.5],
]
# name, path, cot_type, new_bool
agent_specs = [
    ['agent_ltoa', learning_to_act, 0, True],
    ['agent_snd_m2', system_neural_diversity, 0, True],
    ['agent_foundation', foundational_models, 0, True],
    ['agent_norbert_m2', norbet_cog, 0, True],
    ['agent_cot', cot_path, 1, True]
]

test_pack = Pack(agent_specs, embedding_params)
# Out:
# 🔥  Conjuring up agent_ltoa  🔥
#
# 🧙 creating course  🧙
#
# 🔮 creating encoder  🔮
# loading agent_ltoa ...
# agent agent_ltoa loaded
#
# 🧚 creating chat_bot   🧚
#
# the path  being used for agent_ltoa is chroma_db/agent_ltoa
# 🌈
# 🔥  Conjuring up agent_snd_m2  🔥
#
# 🧙 creating course  🧙
#
# 🔮 creating encoder  🔮
# loading agent_snd_m2 ...
# agent agent_snd_m2 loaded
#
# 🧚 creating chat_bot   🧚
#
# the path  being used for agent_snd_m2 is chroma_db/agent_snd_m2
# 🌈
# 🔥  Conjuring up agent_foundation  🔥
#
# 🧙 creating course  🧙
#
# 🔮 creating encoder  🔮
# loading agent_foundation ...
# agent agent_foundation loaded
#
# 🧚 creating chat_bot   🧚
#
# the path  being used for agent_foundation is chroma_db/agent_foundation
# 🌈
# 🔥  Conjuring up agent_norbert_m2  🔥
#
# 🧙 creating course  🧙
#
# 🔮 creating encoder  🔮
# loading agent_norbert_m2 ...
# agent agent_norbert_m2 loaded
#
# 🧚 creating chat_bot   🧚
#
# the path  being used for agent_norbert_m2 is chroma_db/agent_norbert_m2
# 🌈
# 🔥  Conjuring up agent_cot  🔥
#
# 🧙 creating course  🧙
#
# 🔮 creating encoder  🔮
# loading agent_cot ...
# agent agent_cot loaded
#
# 🧚 creating chat_bot   🧚
#
# the path  being used for agent_cot is chroma_db/agent_cot
# 🌈
# waking up agent agent_ltoa
#
# waking up agent agent_snd_m2
#
# waking up agent agent_foundation
#
# waking up agent agent_norbert_m2
#
# waking up agent agent_cot
#
# []

# %%
test_pack.one_question(prompt="how can a network of npl agents share knowdlege in a neural network?",
                       neuron_representation=True)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# loading agent agent_ltoa ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# loading agent agent_snd_m2 ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# loading agent agent_foundation ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# loading agent agent_norbert_m2 ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# loading agent agent_cot ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# ['how', 'can', 'a', 'network', 'of', 'npl', 'agents', 'share', 'knowdlege', 'in', 'a', 'neural', 'network?The', 'network', 'described', 'in', 'the', 'provided', 'context', 'focuses', 'on', 'evolving', 'diverse', 'neural', 'units', 'within', 'random', 'neural', 'networks.', 'These', 'neural', 'units', 'are', 'optimized', 'through', 'neuro-centric', 'parameters,', 'and', 'the', 'network', 'is', 'equipped', 'with', 'memory', 'capabilities', 'through', 'stateful', 'neurons.', 'However,', 'the', 'concept', 'of', '"sharing', 'knowledge"', 'in', 'the', 'traditional', 'sense', 'of', 'multi-agent', 'systems', 'or', 'collaborative', 'learning', 'is', 'not', 'explicitly', 'addressed', 'in', 'this', 'particular', 'context.', 'Therefore,', "it's", 'unclear', 'how', 'a', 'network', 'of', 'npl', 'agents', 'would', 'directly', 'share', 'knowledge', 'in', 'the', 'neural', 'network', 'framework', 'described.The', 'sharing', 'of', 'knowledge', 'in', 'a', 'neural', 'network', 'of', 'NLP', 'agents', 'can', 'be', 'achieved', 'through', 'various', 'methods,', 'some', 'of', 'which', 'are', 'discussed', 'in', 'the', 'context', 'you', 'provided.', 'These', 'methods', 'include:', '1.', 'Compositional', 'Computation:', 'This', 'involves', 'the', 'specialization', 'of', 'sub-networks', 'to', 'different', 'operations,', 'adapting', 'and', 'tailoring', 'the', 'model', 'behavior', 'to', 'the', 'input', 'at', 'hand.', '2.', 'Training', '&', 'Data:', 'Instead', 'of', 'training', 'one', 'model', 'over', 'a', 'complete', 'dataset,', 'the', 'data', 'can', 'be', 'split', 'or', 'decomposed', 'into', 'subsets,', 'and', 'different', 'models', 'can', 'be', 'trained', 'on', 'each', 'one', 'independently', 'and', 'then', 'recombined', 'at', 'test', 'time.', '3.', 'Representation:', 'The', 'learned', 'representation', 'itself', 'can', 'be', 'compositional,', 'potentially', 'through', 'structured,', 'graph-based,', 'object-oriented', 'representations', 'that', 'organize', 'information', 'about', 'the', 'world', 'and', 'support', 'multi-hop', 'reasoning', 'and', 'inference.', 'These', 'are', 'some', 'ways', 'in', 'which', 'knowledge', 'sharing', 'and', 'compositional', 'representation', 'can', 'be', 'implemented', 'in', 'a', 'neural', 'network', 'for', 'NLP', 'agents.One', 'way', 'for', 'a', 'network', 'of', 'NLP', 'agents', 'to', 'share', 'knowledge', 'in', 'a', 'neural', 'network', 'is', 'through', 'the', 'use', 'of', 'pre-trained', 'language', 'models.', 'These', 'models,', 'such', 'as', 'BERT,', 'GPT-2,', 'and', 'RoBERTa,', 'have', 'been', 'trained', 'on', 'large', 'amounts', 'of', 'text', 'data', 'and', 'have', 'learned', 'to', 'represent', 'words', 'and', 'phrases', 'in', 'a', 'way', 'that', 'captures', 'their', 'contextual', 'meaning.', 'By', 'using', 'these', 'pre-trained', 'models', 'as', 'a', 'starting', 'point,', 'NLP', 'agents', 'can', 'leverage', 'the', 'knowledge', 'encoded', 'in', 'the', "model's", 'parameters', 'and', 'fine-tune', 'them', 'on', 'specific', 'tasks', 'or', 'domains.', 'This', 'allows', 'for', 'the', 'transfer', 'of', 'knowledge', 'from', 'the', 'pre-trained', 'model', 'to', 'the', 'specific', 'NLP', 'agents,', 'enabling', 'them', 'to', 'benefit', 'from', 'the', 'broader', 'knowledge', 'encoded', 'in', 'the', 'pre-trained', 'model.I', "don't", 'know,', 'but', 'it', 'sounds', 'like', "you're", 'asking', 'about', 'knowledge', 'sharing', 'in', 'neural', 'networks,', 'which', 'is', 'a', 'complex', 'topic', 'related', 'to', 'artificial', 'intelligence', 'and', 'machine', 'learning.', 'It', 'may', 'involve', 'techniques', 'such', 'as', 'transfer', 'learning,', 'parameter', 'sharing,', 'or', 'collaborative', 'training', 'among', 'agents.', 'If', "you're", 'looking', 'for', 'detailed', 'information,', "I'd", 'recommend', 'consulting', 'a', 'specialist', 'in', 'the', 'field', 'of', 'artificial', 'intelligence', 'or', 'neural', 'networks.I', "don't", 'know', 'the', 'answer', 'to', 'that', 'question.']
# delta dot product [1.06845966 0.03424776]
# delta dot product [1.75794621 0.05083064]
# delta dot product [1.60635697 0.04820033]
# delta dot product [0.54523227 0.01248797]
# delta dot product [0.09290954 0.00337157]
# defaultdict(None,
#             {'agent_ltoa': "In a neural network, knowledge sharing between agents, or neurons, can be achieved through techniques such as transfer learning, weight sharing, and joint training. Transfer learning involves training a neural network on one task and then transferring the knowledge gained to a related task. Weight sharing involves using the same set of weights for multiple agents, allowing them to share information. Joint training involves training multiple agents together on a task, allowing them to learn from each other's experiences. However, in the specific context of the paper you've provided, the focus is on optimizing neuro-centric parameters alone without optimizing any of the neural network weights, so the knowledge sharing may be different from traditional neural network architectures. If you're looking for details on how knowledge sharing is specifically implemented in the context of the paper, I would recommend referring to the specific methods and details provided in the paper itself.",
#              'agent_snd_m2': 'One way that natural language processing (NLP) agents can share knowledge in a neural network is through compositional computation. This involves the specialization of sub-networks to different operations, which allows the model behavior to adapt and tailor itself to the input at hand. Additionally, learning through alternative approaches can enable network specialization to naturally emerge, which can help in sharing knowledge among NLP agents. However, the specifics of how NLP agents share knowledge within a neural network would require a more detailed understanding of the particular NLP system and neural network architecture being used.',
#              'agent_foundation': 'In the context of NLP, a network of NLP agents can share knowledge in a neural network through techniques like transfer learning and multi-task learning. Transfer learning involves training a model on a large dataset and then fine-tuning it on a smaller dataset specific to the task at hand. This allows the model to transfer knowledge learned from the large dataset to the specific task.\n\nMulti-task learning involves training a model on multiple related tasks simultaneously, allowing the model to learn shared representations across tasks and share knowledge between them.\n\nAdditionally, techniques like knowledge distillation can be used, where a large, complex model (teacher model) shares its knowledge with a smaller, simpler model (student model) by training the student model to mimic the outputs of the teacher model.\n\nThese are some of the ways in which NLP agents in a neural network can share knowledge to improve their performance on specific tasks.',
#              'agent_norbert_m2': "I don't know, I'm not able to answer that question.",
#              'agent_cot': "I don't know.",
#              'prompt': 'how can a network of npl agents share knowdlege in a neural network?'})

# %% [markdown]
# ## Neuron Representation

# %%
from utils.myelin_sheath import MyelinSheath

# %%
ms = MyelinSheath(test_pack)
ms.pack.update_edges()
ms.pack.graph()
# Out:
#  eigen_values: {'agent_ltoa': 0.3717480387134094, 'agent_foundation': 0.6015009523789081, 'agent_snd_m2': 0.6015009523789081, 'agent_norbert_m2': 0.3717480387134094}
# Degree Centrality: {'agent_ltoa': 0.6666666666666666, 'agent_foundation': 1.6666666666666665, 'agent_snd_m2': 1.6666666666666665, 'agent_norbert_m2': 0.6666666666666666}

# %%
ms.pack.graph_neuron_representatation()

# %%
ms.agent_transfer()
# Out:
# agent_ltoa
# <utils.neuron.Neuron object at 0x7fb7e6283a00>
# agent_snd_m2
# <utils.neuron.Neuron object at 0x7fb830fa7b80>
# agent_norbert_m2
# <utils.neuron.Neuron object at 0x7fb7e470b820>
